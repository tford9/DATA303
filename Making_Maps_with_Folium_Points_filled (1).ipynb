# %%
#you will need this on JupyterHub every time, just once on your own system
# !pip install folium
# Out:
# Requirement already satisfied: folium in /opt/conda/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from folium) (2.28.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: branca>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from folium) (0.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->folium) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->folium) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->folium) (3.4)

# %%
import pandas as pd
import folium

# %% [markdown]
# ## Plotting points from coordinates in data

# %%
#Data from gis.vb.opendata.gov

# %%
fire = pd.read_csv('data/fire_bomb.csv')
fire.head()
# Out:
#           Incident Type  Exposure Number  Battalion Station Area  \
# 0  Bomb scare - no bomb                0        3.0         ST19
# 1  Bomb scare - no bomb                0        2.0         ST07
# 2  Bomb scare - no bomb                0        2.0         ST07
# 3  Bomb scare - no bomb                0        3.0         ST19
# 4  Bomb scare - no bomb                0        NaN         ST11
#
#                             Action Taken - Primary  \
# 0                                      Investigate
# 1                                      Investigate
# 2                                      Investigate
# 3  Information, investigation & enforcement, other
# 4                                      Investigate
#
#                                           Location 1              Coordinates  \
# 0  5000 FERRELL PW\nVIRGINIA BEACH, VA 23464-\n(3...  [36.795457, -76.165328]
# 1  4800 COLUMBUS ST\nVIRGINIA BEACH, VA 23462-\n(...  [36.841082, -76.141192]
# 2  5100 CLEVELAND ST\nVIRGINIA BEACH, VA 23462-\n...  [36.842197, -76.160385]
# 3  900 AVERY WY\nVIRGINIA BEACH, VA 23464-\n(36.7...  [36.769781, -76.176491]
# 4  800 VIRGINIA BEACH BL\nVIRGINIA BEACH, VA 2345...  [36.843333, -75.985762]
#
#     Latitude  Longitude
# 0  36.795457 -76.165328
# 1  36.841082 -76.141192
# 2  36.842197 -76.160385
# 3  36.769781 -76.176491
# 4  36.843333 -75.985762

# %%
fire["Location 1"].value_counts()
# Out:
# 3600 SENTARA WY\nVIRGINIA BEACH, VA 23452-\n(36.834006, -76.096595)           7
# 2400 NIMMO PW\nVIRGINIA BEACH, VA 23456-\n(36.755972, -76.061489)             6
# 4500 VIRGINIA BEACH BL\nVIRGINIA BEACH, VA 23462-\n(36.843585, -76.131499)    3
# 5100 CLEVELAND ST\nVIRGINIA BEACH, VA 23462-\n(36.842197, -76.160385)         3
# 1000 INDEPENDENCE BL\nVIRGINIA BEACH, VA 23455-\n(36.872251, -76.133985)      2
#                                                                              ..
# 4400 BONNEY RD\nVIRGINIA BEACH, VA 23462-\n(36.835922, -76.127379)            1
# 2400 TOURNAMENT DR\nVIRGINIA BEACH, VA 23456-\n(36.759584, -76.074787)        1
# 3500 CLUB HOUSE RD\nVIRGINIA BEACH, VA 23452-\n(36.824549, -76.091047)        1
# 4800 SHORE DR\nVIRGINIA BEACH, VA 23455-\n(36.904467, -76.135929)             1
# 5300 LAKE LAWSON RD\nVIRGINIA BEACH, VA 23455-\n(36.886165, -76.160951)       1
# Name: Location 1, Length: 162, dtype: int64

# %%
fire['Incident Type'].unique()
# Out:
# array(['Bomb scare - no bomb',
#        'Explosive, bomb removal (for bomb scare, use 721)',
#        'Munitions or bomb explosion (no fire)'], dtype=object)

# %%
recode = {'Bomb scare - no bomb': 'Bomb Scare', 'Explosive, bomb removal (for bomb scare, use 721)':'Bomb Removal',
         'Munitions or bomb explosion (no fire)': 'Explosion'}
fire['Incident Type'] = fire['Incident Type'].apply(lambda x: recode[x])

# %%
fire['Incident Type'].unique()
# Out:
# array(['Bomb Scare', 'Bomb Removal', 'Explosion'], dtype=object)

# %%
fire = fire.rename(columns={'Action Taken - Primary':'Action', 'Location 1':'Location'})

# %%
#first, how do we make a map?
m = folium.Map(tiles = 'CartoDB positron')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2905379ea0bd6157e31d4e5844923cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2905379ea0bd6157e31d4e5844923cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2905379ea0bd6157e31d4e5844923cd = L.map(
#                 &quot;map_f2905379ea0bd6157e31d4e5844923cd&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e8923a8f7b567e5523a0154df5935ad = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f2905379ea0bd6157e31d4e5844923cd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#all our data is from Virginia Beach, so let's center on that
VA_BEACH = [36.8516,-75.9792]
m = folium.Map(VA_BEACH, zoom_start = 12)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a6849abc58ef2de99262569fa11c756 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a6849abc58ef2de99262569fa11c756&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a6849abc58ef2de99262569fa11c756 = L.map(
#                 &quot;map_2a6849abc58ef2de99262569fa11c756&quot;,
#                 {
#                     center: [36.8516, -75.9792],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc36bbe540be20674b0398d50343db99 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2a6849abc58ef2de99262569fa11c756);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#let's add a marker on the map for every item in the df
#then we will add a popup and tooltip (it's extraneous, just by way of example)
VA_BEACH = [36.8516,-75.9792]
m = folium.Map(VA_BEACH, zoom_start = 12)
for i in range(fire.shape[0]):
    lat,lon = fire.loc[i,'Latitude'],fire.loc[i,'Longitude']
    incident = fire.loc[i,'Incident Type']
    action = fire.loc[i, 'Action'] 
    folium.Marker([lat,lon], popup = incident, tooltip = action).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a538db7ef270a729876f3ae330c5095f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a538db7ef270a729876f3ae330c5095f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a538db7ef270a729876f3ae330c5095f = L.map(
#                 &quot;map_a538db7ef270a729876f3ae330c5095f&quot;,
#                 {
#                     center: [36.8516, -75.9792],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85408fc638f3fa1aa57de21b1bb96cff = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a538db7ef270a729876f3ae330c5095f);
#
#
#             var marker_20e657d33c7b720fc80f95fc3cf535c3 = L.marker(
#                 [36.795457, -76.165328],
#                 {}
#             ).addTo(map_a538db7ef270a729876f3ae330c5095f);
#
#
#         var popup_a2374b5094bb11e0cf2d5c340c447a81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c1847483ced7bcd97d2afb17bb39668 = $(`&lt;div id=&quot;html_6c1847483ced7bcd97d2afb17bb39668&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bomb Scare&lt;/div&gt;`)[0];
#                 popup_a2374b5094bb11e0cf2d5c340c447a81.setContent(html_6c1847483ced7bcd97d2afb17bb39668);
#
#
#
#         marker_20e657d33c7b720fc80f95fc3cf535c3.bindPopup(popup_a2374b5094bb11e0cf2d5c340c447a81)
#         ;
#
#
#
#
#             marker_20e657d33c7b720fc80f95fc3cf535c3.bindTooltip(
#                 `&lt;div&gt;
#                      Investigate
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c4b8ef8289708b499e9ac46b45e0979c = L.marker(
#                 [36.841082, -76.141192],
#                 {}
#             ).addTo(map_a538db7ef270a729876f3ae330c5095f);
#
#
#         var popup_60121e766a3e3cef54c0b4b8925acb44 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c89b1e33b205a04c9e1ffce2af96fc46 = $(`&lt;div id=&quot;html_c89b1e33b205a04c9e1ffce2af96fc46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bomb Scare&lt;/div&gt;`)[0];
#                 popup_60121e766a3e3cef54c0b4b8925acb44.setContent(html_c89b1e33b205a04c9e1ffce2af96fc46);
#
#
#
#         marker_c4b8ef8289708b499e9ac46b45e0979c.bindPopup(popup_60121e766a3e3cef54c0b4b8925acb44)
#         ;
#
#
#
#
#             marker_c4b8ef8289708b499e9ac46b45e0979c.bindTooltip(
#                 `&lt;div&gt;
#                      Investigate
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_50af3cbe033833741790fc5d48b3175a = L.marker(
#                 [36.842197, -76.160385],
#                 {}
#             ).addTo(map_a538db7ef270a729876f3ae330c5095f);
#
#
#         var popup_ab64b2ad2797a053589548baa93ce0bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79720e96f25ed5a5567bc642ceb14e07 = $(`&lt;div id=&quot;html_79720e96f25ed5a5567bc642ceb14e07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bomb Scare&lt;/div&gt;`)[0];
#                 popup_ab64b2ad2797a053589548baa93ce0bf.setContent(html_79720e96f25ed5a5567bc642ceb14e07);
#
#
#
#         marker_50af3cbe033833741790fc5d48b3175a.bindPopup(popup_ab64b2ad2797a053589548baa93ce0bf)
#         ;
#
#
#
#
#             marker_50af3cbe033833741790fc5d48b3175a.bindTooltip(
#                 `&lt;div&gt;
#                      Investigate
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_539cd9fb5fa5e50f9e3c1b5f5b99d398 = L.marker(
#                 [36.769781, -76.176491],
#                 {}
#             ).addTo(map_a538db7ef270a729876f3ae330c5095f);
#
#
#         var popup_c65878982bdac7f5e915a7f664d50031 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26ce7991027770678ace23acc292f206 = $(`&lt;div id=&quot;html_26ce7991027770678ace23acc292f206&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bomb Scare&lt;/div&gt;`)[0];
#                 popup_c65878982bdac7f5e915a7f664d50031.setContent(html_26ce7991027770678ace23acc292f206);
#
#
#
#         marker_539cd9fb5fa5e50f9e3c1b5f5b99d398.bindPopup(popup_c65878982bdac7f5e915a7f664d50031)
#         ;
#
#
#
#
#             marker_539cd9fb5fa5e50f9e3c1b5f5b99d398.bindTooltip(
#                 `&lt;div&gt;
#                      Information, investigation &amp; enforcement, other
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;

# %%
#let's use circle markers instead with colors
colors = {'Bomb Scare':'grey', 'Bomb Removal':'blue', 'Explosion':'red'}
#copy-paste our map/loop code here
VA_BEACH = [36.8516,-75.9792]
m = folium.Map(VA_BEACH, zoom_start = 12)
for i in range(fire.shape[0]):
    lat,lon = fire.loc[i,'Latitude'],fire.loc[i,'Longitude']
    incident = fire.loc[i,'Incident Type']
    action = fire.loc[i, 'Action'] 
    color = colors[incident]
    folium.CircleMarker([lat,lon], 
                  tooltip = action, fill_color = color, color = color, 
                    radius = 3, fill_opacity = 1).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1e7f62c86ab257e47211dcf41192a50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1e7f62c86ab257e47211dcf41192a50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1e7f62c86ab257e47211dcf41192a50 = L.map(
#                 &quot;map_d1e7f62c86ab257e47211dcf41192a50&quot;,
#                 {
#                     center: [36.8516, -75.9792],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68801238b4a1731d8cfe1b019e731ce6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d1e7f62c86ab257e47211dcf41192a50);
#
#
#             var circle_marker_4553de5a0ec265596f7c489cfdf00b95 = L.circleMarker(
#                 [36.795457, -76.165328],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d1e7f62c86ab257e47211dcf41192a50);
#
#
#             circle_marker_4553de5a0ec265596f7c489cfdf00b95.bindTooltip(
#                 `&lt;div&gt;
#                      Investigate
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_576a2d4173a137cf51858732674f59e2 = L.circleMarker(
#                 [36.841082, -76.141192],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d1e7f62c86ab257e47211dcf41192a50);
#
#
#             circle_marker_576a2d4173a137cf51858732674f59e2.bindTooltip(
#                 `&lt;div&gt;
#                      Investigate
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3ed264b0c0eababb0f3b3471f79f1681 = L.circleMarker(
#                 [36.842197, -76.160385],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d1e7f62c86ab257e47211dcf41192a50);
#
#
#             circle_marker_3ed264b0c0eababb0f3b3471f79f1681.bindTooltip(
#                 `&lt;div&gt;
#                      Investigate
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3399f8dd311f5490aca89e4ab540f411 = L.circleMarker(
#                 [36.769781, -76.176491],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d1e7f62c86ab257e47211dcf41192a50);
#
#
#             circle_marker_3399f8dd311f5490aca89e4ab540f411.bindTooltip(
#                 `&lt;div&gt;
#                      Information, investigation &amp; enforcement, other
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_69494cb79ac07a16f38903386fb45c90 = L.circleMarker(
#                 [36.843333, -75.985762],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot

# %%
#let's make the FeatureGroups
#m = #copy from above
VA_BEACH = [36.8516,-75.9792]
m = folium.Map(VA_BEACH, zoom_start = 12)

colors = {'Bomb Scare':'grey', 'Bomb Removal':'blue', 'Explosion':'red'}
key_list = list(colors.keys())
groups = [folium.FeatureGroup(name = f'<span style="color: {colors[k]};\
font-size:large">{k}</span>') for k in key_list]
    
for g in range(len(groups)):
    m.add_child(groups[g]) #add each group as a child of the map
    cur_obs = fire[fire['Incident Type'] == key_list[g]].reset_index(drop = True)
    for i in range(cur_obs.shape[0]):
        lat,lon = cur_obs.loc[i,'Latitude'],cur_obs.loc[i,'Longitude']
        incident = cur_obs.loc[i,'Incident Type']
        action = cur_obs.loc[i, 'Action'] 
        color = colors[incident]
        folium.CircleMarker([lat,lon], 
                  tooltip = action, fill_color = color, color = color, 
                    radius = 3, fill_opacity = 1).add_to(groups[g])

title_text = 'Bomb-related incidents in Virginia Beach'
title_html = f'<h3 align="center" style="font-size:24px;font-weight:bold">{title_text}</h3>'
m.get_root().html.add_child(folium.Element(title_html))

folium.LayerControl(collapsed = False).add_to(m)
m.save('fire_bomb.html')
m

# %%
#copy previous here

#Add title
title_text = 'Bomb-related incidents in Virginia Beach'
title_html = f'<h3 align="center" style="font-size:24px;font-weight:bold">{title_text}</h3>'
m.get_root().html.add_child(folium.Element(title_html))

#Save it
m.save('bomb.html')
m
